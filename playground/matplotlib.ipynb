# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.array([0,1,2,3,4,5])
y = np.array([0,1,4,9,16,25])

plt.subplot(4, 2, 1)
plt.title("First Plot")
plt.plot(x, y)

x = np.array([0,1,2,3,4,5])
y = np.array([0,1,4,9,16,25])

plt.subplot(4, 2, 2)
plt.title("Second Plot")
plt.plot(x, y)

x = np.array([0,1,2,3,4,5])
y = np.array([0,1,4,9,16,25])

plt.subplot(4, 2, 3)
plt.title("Third Plot")
plt.plot(x, y)

x = np.array([0,1,2,3,4,5])
y = np.array([0,1,4,9,16,25])

plt.subplot(4, 2, 4)
plt.title("Fourth Plot",pad=20)
plt.plot(x, y)

x = np.array([0,1,2,3,4,5])
y = np.array([0,1,4,9,16,25])

plt.subplot(4, 2, 5)
plt.title("Fifth Plot")
plt.plot(x, y)

x = np.array([0,1,2,3,4,5])
y = np.array([0,1,4,9,16,25])

plt.subplot(4, 2, 6)
plt.title("Sixth Plot")
plt.plot(x, y)

x = np.array([0,1,2,3,4,5])
y = np.array([0,1,4,9,16,25])

plt.subplot(4, 2, 8)
plt.title("Seventh Plot")
plt.plot(x, y)

# %%
df = pd.read_csv(r"D:\Py Django\profit_and_loss.csv")
x = df["Year"]
y = df["Profit/Loss"]
plt.plot(x,y)
plt.show()

# %%
def pro(x):
    if x >= 0:
        return x
    else:
        return 0

def loss(x):
    if x <= 0:
        return x
    else:
        return 0

df["Profit"] = df["Profit/Loss"].apply(pro)
df["Loss"] = df["Profit/Loss"].apply(loss)
df

# x = df["Year"]
# y = df["Profit"]
# plt.plot(x,y)
# plt.show()

x = df["Year"]
y = df["Loss"]
plt.plot(x,y)
plt.show()

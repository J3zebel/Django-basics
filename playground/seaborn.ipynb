# %%
#pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot([0,1,2,3,4,5])
plt.show()
# Out:
# C:\Users\91702\AppData\Local\Temp\ipykernel_14968\230963844.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5])

# %%
sns.distplot([0,1,2,3,4,5],hist=False)
plt.show()
# Out:
# C:\Users\91702\AppData\Local\Temp\ipykernel_14968\299229084.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5],hist=False)

# %%
sns.displot([0,1,2,3,4,5],kde=True)
plt.show()

# %%
sns.distplot([0,1,2,3,4,5])
sns.set_style(style='dark')
plt.show()
# Out:
# C:\Users\91702\AppData\Local\Temp\ipykernel_14968\2508682566.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5])

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("iris")
df.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
sns.lineplot(x="sepal_length",y="sepal_width",data=df)
sns.set_style("whitegrid")
plt.show()

# %%
sns.histplot(x="sepal_length",data=df)
sns.set_style("whitegrid")
plt.show()

# %% [markdown]
# Multiple Plots
#
# 1.Using add_axes()

# %%
data = sns.load_dataset("iris")
data
fig = plt.figure(figsize=(5,4))
ax1 = fig.add_axes((0.1,0.1,0.8,0.8))
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
ax2=fig.add_axes((0.8,0.8,0.3,0.3))
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
plt.show()

# %%
data = sns.load_dataset("iris")
plt.subplot(1,2,1)
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
plt.subplot(2,2,2)
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
plt.show()

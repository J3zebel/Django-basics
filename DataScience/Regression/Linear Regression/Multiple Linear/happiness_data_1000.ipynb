# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("D:\Py Django\DataScience\Regression\Linear Regression\Multiple Linear\happiness_data_1000.csv")
df
# Out:
#      GDP_per_capita  Social_support  Healthy_life_expectancy  Freedom  \
# 0          30275.94            0.19                    51.78     0.67
# 1          76081.79            0.54                    51.11     0.80
# 2          58693.52            0.87                    80.78     0.25
# 3          48093.35            0.73                    51.23     0.62
# 4          12903.48            0.81                    52.24     0.57
# ..              ...             ...                      ...      ...
# 995         7780.77            0.66                    78.94     0.44
# 996        73426.43            0.96                    47.08     0.33
# 997        11377.08            0.07                    53.94     0.39
# 998        76043.87            0.06                    53.05     0.53
# 999        35957.46            0.28                    79.21     0.16
#
#      Generosity  Corruption_perception  Happiness_Score
# 0          0.26                   0.39             4.48
# ...

# %%
x = df.drop("Happiness_Score",axis = 1)
y = df["Happiness_Score"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=32)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([5.56620596, 4.03679896, 4.61016061, 6.27472244, 7.00559445,
#        4.77934135, 5.72196971, 8.88861848, 4.76991678, 4.46027137,
#        5.21974574, 4.43003997, 8.01412324, 8.49129821, 3.43568736,
#        7.34290511, 4.62936101, 5.23105696, 5.66368008, 8.09624031,
#        7.49926578, 5.06531669, 6.34447864, 6.63167494, 6.48096314,
#        5.68272248, 4.5003431 , 7.85673347, 6.30150086, 6.18261753,
#        6.25697818, 5.00463334, 5.0665323 , 6.06036233, 6.41303512,
#        5.57098861, 6.7557793 , 5.1851387 , 7.16265768, 5.40657294,
#        6.99866666, 6.82905213, 5.43320808, 4.30858681, 5.02395788,
#        4.44356968, 4.90451751, 5.47349871, 5.02209403, 4.20380476,
#        5.95952827, 5.6358443 , 5.71994451, 5.80845826, 4.82824351,
#        7.38933052, 3.8566983 , 4.55777202, 3.52891755, 4.70117479,
#        4.28109121, 7.57588983, 8.69667078, 8.08510456, 7.15058705,
#        7.83294978, 6.10592107, 3.99169745, 4.40309949, 6.27458095,
# ...

# %%
mse = mean_squared_error(y_pred,y_test)
mse

r_mse = r2_score(y_pred,y_test)
r_mse
# Out:
# 0.9443135402048973

# %%
new_data = np.array([30000,0.5,45,0.5,0.8,0.3])
predicted_happiness = model.predict([new_data])
print(f"Predicted Happiness Score for the new data point : {predicted_happiness[0]}")


plt.figure(figsize=(10,6))
plt.scatter(y_test,y_pred , alpha = 0.7)
plt.scatter(predicted_happiness[0],predicted_happiness[0], color="red", s=200, marker="*", label="New Data Point")
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()], 'r--',lw=2)
plt.xlabel("Actual Happiness Score")
plt.ylabel("Predicted Happiness Score")
plt.title("Actual vs Predicted Happiness Score")
plt.legend()
plt.grid()
plt.show()
# Out:
# c:\Users\91702\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted Happiness Score for the new data point : 5.558174309329497

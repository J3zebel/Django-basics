# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,log_loss
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
df =  pd.read_csv("D:\Py Django\DataScience\Regression\Logistic Regression\churn_data.csv")
df.isna().sum()
df
# Out:
#     CustomerID  Gender AgeGroup Region SubscriptionType  MonthlyUsage  \
# 0     CUST0001    Male    Young  North            Basic          40.7
# 1     CUST0002  Female   Senior   West         Standard          16.5
# 2     CUST0003    Male   Middle   East            Basic          46.9
# 3     CUST0004    Male   Senior  North         Standard          38.0
# 4     CUST0005    Male    Young   East            Basic          70.9
# ..         ...     ...      ...    ...              ...           ...
# 795   CUST0796    Male   Senior   West         Standard          55.5
# 796   CUST0797    Male   Senior   West            Basic          94.7
# 797   CUST0798    Male   Senior  North            Basic          88.9
# 798   CUST0799    Male   Middle  North         Standard          19.2
# 799   CUST0800    Male    Young   West         Standard          45.3
#
#      SupportCalls Churn
# 0               2   Yes
# 1               2    No
# 2               6   Yes
# 3               5    No
# 4               8   Yes
# ..            ...   ...
# 795             5    No
# 796             9    No
# 797             4    No
# 798             3    No
# 799             7    No
#
# [800 rows x 8 columns]

# %%
Gender	= LabelEncoder()
AgeGroup = LabelEncoder()
Region = LabelEncoder()
SubscriptionType = LabelEncoder()
Churn = LabelEncoder()

df["Gender"] = Gender.fit_transform(df["Gender"])
df["AgeGroup"] = AgeGroup.fit_transform(df["AgeGroup"])
df["Region"] = Region.fit_transform(df["Region"])
df["SubscriptionType"] = SubscriptionType.fit_transform(df["SubscriptionType"])
df["Churn"] = Churn.fit_transform(df["Churn"])

# %%
x =  df.drop(["Churn","CustomerID"],axis = 1)
y = df["Churn"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=23)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0.15305396, 0.16581907, 0.09012617, 0.11913589, 0.1314336 ,
#        0.12731048, 0.08055973, 0.14773639, 0.1307534 , 0.1154637 ,
#        0.07397996, 0.05960393, 0.16268803, 0.16475097, 0.18350738,
#        0.13360975, 0.08305186, 0.15382771, 0.13359631, 0.06377289,
#        0.15020842, 0.15073793, 0.11333647, 0.13739797, 0.12207683,
#        0.17871666, 0.07340365, 0.12081517, 0.11036085, 0.13270564,
#        0.08038211, 0.11955164, 0.11643901, 0.16851398, 0.13207014,
#        0.13204453, 0.08528943, 0.10143142, 0.10642417, 0.1172462 ,
#        0.0972839 , 0.11735488, 0.1603021 , 0.09738488, 0.143326  ,
#        0.15703599, 0.08292247, 0.08233784, 0.08510127, 0.15164395,
#        0.14949105, 0.12813537, 0.1316639 , 0.1231962 , 0.10059501,
#        0.0914039 , 0.14266901, 0.09235891, 0.09250408, 0.14936215,
#        0.11417612, 0.12130305, 0.11687225, 0.10491783, 0.11211768,
#        0.14055879, 0.12575517, 0.15080413, 0.18452585, 0.12105227,
#        0.08408703, 0.08042521, 0.09824056, 0.09911139, 0.10806951,
#        0.12688248, 0.0945901 , 0.10056981, 0.0820761 , 0.08545434,
#        0.14286492, 0.10718211, 0.10444761, 0.14961268, 0.18435096,
#        0.09069553, 0.19780153, 0.08797816, 0.12887075, 0.14727559,
#        0.13902224, 0.08547606, 0.12312689, 0.14286824, 0.11507415,
#        0.16626927, 0.07574466, 0.12194691, 0.08333992, 0.073873  ,
#        0.1115282 , 0.06804643, 0.15082474, 0.12267316, 0.14251861,
#        0.14546733, 0.07375279, 0.12328874, 0.0943201 , 0.05553043,
#        0.09819031, 0.15944491, 0.1082282 , 0.09745645, 0.1944266 ,
#        0.15079103, 0.1353251 , 0.11240005, 0.1404978 , 0.09087647,
#        0.1348054 , 0.08885304, 0.11858957, 0.15989791, 0.11376066,
#        0.20131343, 0.19339261, 0.09790764, 0.14409396, 0.12676064,
#        0.13423381, 0.15690004, 0.08286926, 0.09195157, 0.13518687,
#        0.12544726, 0.10242119, 0.10279095, 0.06486245, 0.12556382,
#        0.12921399, 0.1319737 , 0.12487887, 0.13377422, 0.12699768,
#        0.09327729, 0.1913866 , 0.10743966, 0.18400757, 0.07836617,
#        0.12133695, 0.07371983, 0.09703238, 0.15610925, 0.12511706,
#        0.13686361, 0.10910148, 0.09491513, 0.09122066, 0.15337774])

# %%
mse = mean_squared_error(y_pred,y_test)
mse
# Out:
# 0.10104660618356184

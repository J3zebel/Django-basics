# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("simple_salary.csv")
df
# Out:
#      Experience_Years  Salary_in_Thousands
# 0               37.45               209.05
# 1               95.07               482.00
# 2               73.20               389.80
# 3               59.87               325.44
# 4               15.60               103.61
# ..                ...                  ...
# 995              9.16                52.59
# 996             91.73               472.54
# 997             13.68                88.04
# 998             95.02               490.83
# 999             44.60               236.08
#
# [1000 rows x 2 columns]

# %%
x = df[["Experience_Years"]]
y = df["Salary_in_Thousands"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=32)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([276.80829542, 161.36124431, 109.74141481, 482.59004815,
#        247.2614239 , 114.82367601, 180.7934195 , 493.85074455,
#        273.61942564,  42.22706252,  86.07402194, 316.2705589 ,
#        374.06882359, 408.2495215 ,  28.32558334, 160.66367904,
#        107.00097984, 311.43742814,  76.70671697, 501.274832  ,
#        231.81533592, 405.50908653, 408.05021714, 325.58803777,
#        270.18142541, 457.27839431, 371.12908426, 504.96196267,
#        478.90291747, 421.90187023, 505.11144095, 332.41421214,
#         49.95010651, 109.2431539 , 494.94691853, 219.40863945,
#         26.43219191, 183.8826371 , 209.84203012, 282.28916534,
#        484.3837874 , 492.60509229,  80.09489111,  49.15288906,
#        454.63761152, 241.18264089, 385.37934607, 400.92508623,
#        168.5362013 , 158.42150498, 199.27889899,  50.54801959,
#        289.61360061, 269.18490361, 315.97160235, 233.21046645,
#        107.69854511, 141.23150384,  66.04393366,  33.95593153,
#        108.2466321 , 349.50456109, 516.62126779, 510.14387606,
#        180.2951586 , 245.26838029, 188.01820259,  36.1981056 ,
#        173.61846251, 354.98543102,  75.61054298, 280.09681737,
#        195.84089876,  27.22940935, 143.02524309,  47.60828026,
#        292.25438339, 185.02863717,  71.37532531, 343.47560417,
#         47.45880199, 389.56473765,  60.2142811 , 247.70985871,
#        490.96083131,  83.98132615,  91.50506577, 300.67499265,
#        371.87647562, 128.92445955,  68.23628163, 417.46734819,
#        453.39195927, 305.80707994, 291.7062964 , 150.49915663,
#        182.48750657, 127.62898121, 465.30039484, 196.68794229,
#        286.97281783, 140.03567768,  74.96280381, 257.77472894,
#        280.993687  , 259.07020729, 391.10934645, 101.91871864,
#        383.43612855, 228.52681396, 110.7877627 , 351.94603951,
#        257.12698977, 406.00734744, 113.97663248, 168.13759258,
#        431.66778392, 147.31028686, 288.96586144, 321.3528201 ,
#        194.0969856 , 140.03567768,  67.28958591, 361.41299666,
#        425.14056609, 124.63941579, 345.51847387, 208.99498659,
#        396.73969465,  27.32906153,  97.83297924, 233.70872735,
#        132.51193805,  82.63602171, 405.25995608, 258.02385939,
#        345.71777823, 206.50368207,  33.05906191, 377.90543254,
#        428.1799576 , 343.67490853, 214.22672606,  95.14237036,
#         44.76819312, 374.21830186, 280.39577391,  72.07289058,
#        343.3261259 , 308.597341  ,  47.65810635, 267.24168609,
#        228.42716178, 295.24394881, 417.86595692, 233.80837953,
#         68.53523817, 173.41915815, 296.8383837 , 513.13344148,
#        335.20447319, 225.63690073, 346.4153435 ,  31.66393138,
#        197.93359455,  85.37645667, 220.6542917 , 133.75759031,
#        410.44186947, 332.81282086, 337.49647334, 367.99004058,
#         68.68471644, 283.33551324, 247.16177172, 415.07569586,
#        160.06576596, 106.30341458, 251.44681548, 140.53393858,
#         65.94428148, 274.76542572, 213.13055208, 318.61238514,
#        504.91213658, 458.72335092,  59.01845493, 144.42037362,
#        316.22073281, 320.15699393, 267.29151218, 394.29821623,
#         68.8840208 , 234.85472743, 480.64683063, 305.90673212,
#        466.59587318, 418.36421782,  49.90028041, 286.6240352 ])

# %%
mse = mean_squared_error(y_pred,y_test)
mse

root = np.sqrt(mse)
root

r_mse = r2_score(y_test, y_pred)
r_mse
# Out:
# 0.9951510063756421

# %%
new_experience = [[10]] 
predicted_salary = model.predict(new_experience)[0]
print(f"Predicted salary for 10 years experience: {predicted_salary:.2f} thousand")


plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, color="green", label="Actual Data")
plt.plot([y_test.min(), y_test.max()],[y_test.min(), y_test.max()], color="red", linewidth=2, label="Regression Line")
plt.xlabel("Experience (Years)")
plt.ylabel("Salary (Thousands)")
plt.title("Experience vs Salary Prediction")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\91702\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted salary for 10 years experience: 71.67 thousand

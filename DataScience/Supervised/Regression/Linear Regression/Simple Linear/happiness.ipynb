# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("happiness.csv")
df
# Out:
#      GDP_per_capita  Happiness_Score
# 0          30275.94             3.60
# 1          76081.79             5.14
# 2          58693.52             5.12
# 3          48093.35             4.71
# 4          12903.48             2.93
# ..              ...              ...
# 995         7780.77             1.73
# 996        73426.43             5.37
# 997        11377.08             2.55
# 998        76043.87             5.59
# 999        35957.46             3.45
#
# [1000 rows x 2 columns]

# %%
x = df[["GDP_per_capita"]]
y = df["Happiness_Score"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=32)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([4.10675891, 3.2058952 , 2.80312006, 5.712602  , 3.87643638,
#        2.84270079, 3.35751695, 5.80043318, 4.08177733, 2.27621219,
#        2.61840749, 4.41475566, 4.86563551, 5.13263176, 2.16786413,
#        3.20071353, 2.78173753, 4.37721727, 2.54520335, 5.85832364,
#        3.75584744, 5.11111473, 5.13109657, 4.48735141, 4.05529872,
#        5.51507342, 4.84274176, 5.88714245, 5.68390791, 5.23887683,
#        5.88840669, 4.54074978, 2.33650446, 2.79917083, 5.80913174,
#        3.65910496, 2.15307081, 3.38165293, 3.58422576, 4.14974307,
#        5.72669645, 5.79064449, 2.57182135, 2.33022972, 5.49450176,
#        3.82866327, 4.95408487, 5.07531106, 3.2621551 , 3.18286255,
#        3.50184719, 2.34110512, 4.20675321, 4.04722763, 4.41243064,
#        3.76672431, 2.78730654, 3.04874943, 2.46219486, 2.2118543 ,
#        2.79140346, 4.67416843, 5.97804644, 5.9277649 , 3.35373743,
#        3.8609075 , 3.41398569, 2.2292211 , 3.30167666, 4.71705576,
# ...

# %%
mse = mean_squared_error(y_pred,y_test)
mse
# Out:
# 0.23824625466397348

# %%
new_gdp = np.array([[50000]])  # Example new GDP per capita value
predicted_happiness = model.predict(new_gdp)[0]
print(f"Predicted Happiness Score for GDP {new_gdp[0][0]}: {predicted_happiness:.2f}")
plt.figure(figsize=(8,6))
plt.scatter(new_gdp, predicted_happiness, color="blue", s=100, marker="*", label="New Prediction")
plt.plot(x_test,y_pred, color="red", linewidth=2, label="Regression Line")
plt.xlabel("GDP per Capita")
plt.ylabel("Happiness Score")
plt.title("GDP vs Happiness Prediction")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\91702\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted Happiness Score for GDP 50000: 4.54

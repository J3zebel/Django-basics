# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor,plot_tree
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("D:\Py Django\DataScience\Classification\Decision Tree\Regression\car_price_dataset_900.csv")
df
# Out:
#         brand  year  mileage_kmpl  engine_cc  horsepower transmission  \
# 0    Mercedes  2023         20.92       3078         107    automatic
# 1    Mercedes  2017         20.65       2844         339       manual
# 2         BMW  2007         10.19        964         398    automatic
# 3     Hyundai  2022         17.27       1577         361    automatic
# 4      Toyota  2018         21.53       2386         135       manual
# ..        ...   ...           ...        ...         ...          ...
# 895  Mercedes  2018         21.48       1949         301       manual
# 896       BMW  2018         16.11       3313         195       manual
# 897  Mercedes  2021         23.21        976         101       manual
# 898  Mercedes  2019         12.66       2521         314    automatic
# 899   Hyundai  2007         14.19       1116         306       manual
#
#     fuel_type owner_type      price
# 0    electric     second  813805.13
# 1      petrol     second  501144.16
# ...

# %%
label_encoders = {}
for column in df.columns[:-1]:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])
df
# Out:
#      brand  year  mileage_kmpl  engine_cc  horsepower  transmission  \
# 0        4    18           525        652          46             0
# 1        4    12           519        582         256             1
# 2        0     2           102         50         307             0
# 3        3    17           388        220         276             0
# 4        5    13           552        441          73             1
# ..     ...   ...           ...        ...         ...           ...
# 895      4    13           550        331         221             1
# 896      0    13           335        715         126             1
# 897      4    16           629         53          40             1
# 898      4    14           203        491         234             0
# 899      3     2           270         94         226             1
#
#      fuel_type  owner_type      price
# 0            1           1  813805.13
# 1            3           1  501144.16
# ...

# %%
x = df.drop("price",axis = 1)
y = df["price"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=30)

# %%
model = DecisionTreeRegressor(random_state=40)
model.fit(x_train , y_train)
# Out:
# DecisionTreeRegressor(random_state=40)

# %%
x_pred = model.predict(x_test)
x_pred
# Out:
# array([587924.94, 416412.48,  50000.  ,  50000.  ,  76922.04, 118813.78,
#        165311.06, 448699.97, 521676.29, 396400.23, 234308.7 , 501144.16,
#        565699.  , 587924.94, 385706.66, 340292.23,  50000.  , 380660.18,
#        363811.7 ,  50000.  ,  50000.  , 685226.48,  73793.64, 335808.3 ,
#         50000.  , 563338.53, 132606.  , 326835.27,  50000.  , 367043.55,
#        166247.77, 400525.58, 175594.43, 596901.47,  96578.05, 501144.16,
#        537012.16, 312278.76,  76922.04, 197080.21, 812072.53, 574945.73,
#        325449.63, 100464.49, 118813.78, 348447.12, 105468.16, 323747.62,
#         50000.  ,  91770.13, 103409.84, 217088.83, 246599.39, 396400.23,
#        248950.05, 493546.4 , 233367.94,  50000.  , 552498.05, 389833.34,
#        388629.92, 266948.86, 543291.09, 500238.96, 565699.  ,  50000.  ,
#        634448.4 ,  50000.  , 266888.21, 248950.05, 307102.4 ,  50000.  ,
#        437881.41, 537012.16, 215679.31,  50000.  , 110625.44, 161058.04,
# ...

# %%
print("Mean Squared Error:",mean_squared_error(y_test,x_pred))
# Out:
# Mean Squared Error: 10926228979.149029

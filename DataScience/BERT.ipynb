# %%
# pip install transformers datasets torch

# %%
import torch
from datasets import load_dataset
from transformers import (
    BertTokenizer,
    BertForSequenceClassification,
    Trainer,
    TrainingArguments
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\91702\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 import torch
#       2 from datasets import load_dataset
# ----> 3 from transformers import (
#       4     BertTokenizer,
#       5     BertForSequenceClassification,
#       6     Trainer,
#       7     TrainingArguments
#       8 )
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# ...

# %%
dataset = Load_dataset("ag_news")
print(dataset)

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# %%
def tokenize_function(example):
    return tokenizer(
        example["text"],
        truncation = True,
        padding = "max_length",
        max_length = 128
    )

# %%
tokenized_dataset = dataset.map(tokenize_function, batched = True)

# %%
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels=4
)

# %%
small_train = tokenized_dataset["train"].shuffle(seed=42).select(range(100))
small_test = tokenized_dataset["test"].shuffle(seed=42).select(range(50))

# %%
training_args = TrainingArguments(
    output_dir="./distilbert-agnews",
    learning_rate=3e-5,
    per_device_train_batch_size=4,
    num_train_epochs=1,
    logging_dir = "./logs"
)

# %%
trainer = Trainer(
    model = model.
    args = training_args,
    train_dataset= small_train,
    eval_dataset=small_test
)

# %%
trainer.train()

# %%
import torch

model.eval()

labels_map = {
    0:"World",
    1:"Sports",
    2:"Business",
    3:"Science/Technology"
}


def predict_news(text):
    inputs = tokenizer(
        text,
        return_tensors = "pt",
        truncaTION = True,
        padding = True
    )


    inputs = {k: v.to(model.device) for k, v in inputs.items()}


    with torch.no_grad():
        outputs = model(**inputs)
        prediction = torch.argmax(outputs.logits,dim=1).item()

    return labels_map(prediction)


print(predict_news("NASA launches a new satellite to explore Mars"))
print(predict_news("Stock markets fall after new inflation report"))
print(predict_news("Inida wins the T20 World Cup final"))
